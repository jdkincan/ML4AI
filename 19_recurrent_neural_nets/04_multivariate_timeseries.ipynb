# %% [markdown]
# # Multivariate Time Series Regression

# %% [markdown]
# So far, we have limited our modeling efforts to single time series. RNNs are naturally well suited to multivariate time series and represent a non-linear alternative to the Vector Autoregressive (VAR) models we covered in Chapter 8, Time Series Models.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import minmax_scale

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM
import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2023-02-17 16:45:07.508533: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU
# 2023-02-17 16:45:10.700685: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:10.834342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:10.834404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
sns.set_style('whitegrid')
np.random.seed(42)

# %%
results_path = Path('results', 'multivariate_time_series')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Load Data

# %% [markdown]
# For comparison, we illustrate the application of RNNs to modeling and forecasting several time series using the same dataset we used for the VAR example, monthly data on consumer sentiment, and industrial production from the Federal Reserve's FRED service in Chapter 8, Time Series Models:

# %%
df = web.DataReader(['UMCSENT', 'IPGMFN'], 'fred', '1980', '2019-12').dropna()
df.columns = ['sentiment', 'ip']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 480 entries, 1980-01-01 to 2019-12-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  480 non-null    float64
#  1   ip         480 non-null    float64
# dtypes: float64(2)
# memory usage: 11.2 KB

# %%
df.head()
# Out:
#             sentiment       ip
# DATE
# 1980-01-01       67.0  46.0471
# 1980-02-01       66.9  47.1305
# 1980-03-01       56.5  47.6433
# 1980-04-01       52.7  46.2537
# 1980-05-01       51.7  44.9161

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Stationarity

# %% [markdown]
# We apply the same transformation—annual difference for both series, prior log-transform for industrial production—to achieve stationarity that we used in Chapter 8 on Time Series Models:

# %%
df_transformed = (pd.DataFrame({'ip': np.log(df.ip).diff(12),
                                'sentiment': df.sentiment.diff(12)})
                  .dropna())

# %% [markdown]
# ### Scaling

# %% [markdown]
# Then we scale the transformed data to the [0,1] interval:

# %%
df_transformed = df_transformed.apply(minmax_scale)

# %% [markdown]
# ### Plot original and transformed series

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
columns={'ip': 'Industrial Production', 'sentiment': 'Sentiment'}
df.rename(columns=columns).plot(ax=axes[0], title='Original Series')
df_transformed.rename(columns=columns).plot(ax=axes[1], title='Tansformed Series')
sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'multi_rnn', dpi=300)

# %% [markdown]
# ### Reshape data into RNN format

# %% [markdown]
# We can reshape directly to get non-overlapping series, i.e., one sample for each year (works only if the number of samples is divisible by window size):

# %%
df.values.reshape(-1, 12, 2).shape
# Out:
# (40, 12, 2)

# %% [markdown]
# However, we want rolling, not non-overlapping lagged values. The create_multivariate_rnn_data function transforms a dataset of several time series into the shape required by the Keras RNN layers, namely `n_samples` x `window_size` x `n_series`, as follows:

# %%
def create_multivariate_rnn_data(data, window_size):
    y = data[window_size:]
    n = data.shape[0]
    X = np.stack([data[i: j] 
                  for i, j in enumerate(range(window_size, n))], axis=0)
    return X, y

# %% [markdown]
# We will use window_size of 24 months and obtain the desired inputs for our RNN model, as follows:

# %%
window_size = 18

# %%
X, y = create_multivariate_rnn_data(df_transformed, window_size=window_size)

# %%
X.shape, y.shape
# Out:
# ((450, 18, 2), (450, 2))

# %%
df_transformed.head()
# Out:
#                   ip  sentiment
# DATE
# 1981-01-01  0.528165   0.576214
# 1981-02-01  0.515488   0.502513
# 1981-03-01  0.544409   0.670017
# 1981-04-01  0.614970   0.832496
# 1981-05-01  0.733339   0.914573

# %% [markdown]
# Finally, we split our data into a train and a test set, using the last 24 months to test the out-of-sample performance, as shown here:

# %%
test_size =24
train_size = X.shape[0]-test_size

# %%
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train.shape, X_test.shape
# Out:
# ((426, 18, 2), (24, 18, 2))

# %% [markdown]
# ## Define Model Architecture

# %% [markdown]
# We use a similar architecture with two stacked LSTM layers with 12 and 6 units, respectively, followed by a fully-connected layer with 10 units. The output layer has two units, one for each time series. We compile them using mean absolute loss and the recommended RMSProp optimizer, as follows:

# %%
K.clear_session()

# %%
n_features = output_size = 2

# %%
lstm_units = 12
dense_units = 6

# %%
rnn = Sequential([
    LSTM(units=lstm_units,
         dropout=.1,
         recurrent_dropout=.1,
         input_shape=(window_size, n_features), name='LSTM',
         return_sequences=False),
    Dense(dense_units, name='FC'),
    Dense(output_size, name='Output')
])
# Out:
# WARNING:tensorflow:Layer LSTM will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-02-17 16:45:13.910992: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-17 16:45:13.911851: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:13.911947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:13.911990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:15.289109: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:15.291194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:15.291591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-02-17 16:45:15.291683: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 16:45:15.293397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5947 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# The model has 1,268 parameters, as shown here:

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM (LSTM)                 (None, 12)                720
#
#  FC (Dense)                  (None, 6)                 78
#
#  Output (Dense)              (None, 2)                 14
#
# =================================================================
# Total params: 812
# Trainable params: 812
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn.compile(loss='mae', optimizer='RMSProp')

# %% [markdown]
# ## Train the Model

# %% [markdown]
# We train for 50 epochs with a batch_size value of 20 using early stopping:

# %%
lstm_path = (results_path / 'lstm.h5').as_posix()

checkpointer = ModelCheckpoint(filepath=lstm_path,
                               verbose=1,
                               monitor='val_loss',
                               mode='min',
                               save_best_only=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=10,
                              restore_best_weights=True)

# %%
result = rnn.fit(X_train,
                 y_train,
                 epochs=10,
                 batch_size=20,
                 shuffle=False,
                 validation_data=(X_test, y_test),
                 callbacks=[early_stopping, checkpointer],
                 verbose=1)
# Out:
# Epoch 1/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0928
# Epoch 1: val_loss improved from 0.04398 to 0.04397, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 3s 127ms/step - loss: 0.0928 - val_loss: 0.0440
# Epoch 2/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0934
# Epoch 2: val_loss did not improve from 0.04397
# 22/22 [==============================] - 3s 129ms/step - loss: 0.0934 - val_loss: 0.0666
# Epoch 3/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0900
# Epoch 3: val_loss did not improve from 0.04397
# 22/22 [==============================] - 3s 125ms/step - loss: 0.0900 - val_loss: 0.0491
# Epoch 4/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0909
# Epoch 4: val_loss did not improve from 0.04397
# 22/22 [==============================] - 3s 130ms/step - loss: 0.0909 - val_loss: 0.0494
# Epoch 5/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0893
# Epoch 5: val_loss improved from 0.04397 to 0.04391, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 3s 130ms/step - loss: 0.0893 - val_loss: 0.0439
# Epoch 6/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0886
# Epoch 6: val_loss did not improve from 0.04391
# 22/22 [==============================] - 3s 135ms/step - loss: 0.0886 - val_loss: 0.0514
# Epoch 7/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0900
# Epoch 7: val_loss did not improve from 0.04391
# 22/22 [==============================] - 3s 126ms/step - loss: 0.0900 - val_loss: 0.0550
# Epoch 8/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0878
# Epoch 8: val_loss improved from 0.04391 to 0.04212, saving model to results/multivariate_time_series/lstm.h5
# 22/22 [==============================] - 3s 130ms/step - loss: 0.0878 - val_loss: 0.0421
# Epoch 9/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 9: val_loss did not improve from 0.04212
# 22/22 [==============================] - 3s 128ms/step - loss: 0.0884 - val_loss: 0.0518
# Epoch 10/10
# 22/22 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 10: val_loss did not improve from 0.04212
# 22/22 [==============================] - 3s 126ms/step - loss: 0.0844 - val_loss: 0.0464

# %% [markdown]
# ## Evaluate the Results

# %% [markdown]
# Training stops early after 22 epochs, yielding a test MAE of 1.71, which compares favorably to the test MAE for the VAR model of 1.91.

# %% [markdown]
# However, the two results are not fully comparable because the RNN model produces 24 one-step-ahead forecasts, whereas the VAR model uses its own predictions as input for its out-of-sample forecast. You may want to tweak the VAR setup to obtain comparable forecasts and compare their performance:

# %%
pd.DataFrame(result.history).plot();

# %%
y_pred = pd.DataFrame(rnn.predict(X_test), 
                      columns=y_test.columns, 
                      index=y_test.index)
y_pred.info()
# Out:
# 1/1 [==============================] - 0s 184ms/step
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2018-01-01 to 2019-12-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ip         24 non-null     float32
#  1   sentiment  24 non-null     float32
# dtypes: float32(2)
# memory usage: 384.0 bytes

# %%
test_mae = mean_absolute_error(y_pred, y_test)

# %%
print(test_mae)
# Out:
# 0.04636173408597915

# %%
y_test.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(17, 4))
pd.DataFrame(result.history).rename(columns={'loss': 'Training',
                                              'val_loss': 'Validation'}).plot(ax=axes[0], title='Train & Validiation Error')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('MAE')
col_dict = {'ip': 'Industrial Production', 'sentiment': 'Sentiment'}

for i, col in enumerate(y_test.columns, 1):
    y_train.loc['2010':, col].plot(ax=axes[i], label='training', title=col_dict[col])
    y_test[col].plot(ax=axes[i], label='out-of-sample')
    y_pred[col].plot(ax=axes[i], label='prediction')
    axes[i].set_xlabel('')

axes[1].set_ylim(.5, .9)
axes[1].fill_between(x=y_test.index, y1=0.5, y2=0.9, color='grey', alpha=.5)

axes[2].set_ylim(.3, .9)
axes[2].fill_between(x=y_test.index, y1=0.3, y2=0.9, color='grey', alpha=.5)

plt.legend()
fig.suptitle('Multivariate RNN - Results | Test MAE = {:.4f}'.format(test_mae), fontsize=14)
sns.despine()
fig.tight_layout()
fig.subplots_adjust(top=.85)
fig.savefig(results_path / 'multivariate_results', dpi=300);
