# %% [markdown]
# # How to use Tensorflow 2

# %% [markdown]
# Keras was designed as a high-level or meta API to accelerate the iterative workflow when designing and training deep neural networks with computational backends like TensorFlow, Theano, or CNTK. It has been integrated into TensorFlow in 2017 and is set to become the principal TensorFlow interface with the 2.0 release. You can also combine code from both libraries to leverage Keras’ high-level abstractions as well as customized TensorFlow graph operations.

# %% [markdown]
# Please follow the installations instructions in `Installation Guide.md` in the root folder.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
from copy import deepcopy
import numpy as np
import pandas as pd

import sklearn
from sklearn.datasets import make_circles # To generate the dataset

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns

# %%
# plotting style
sns.set_style('white')
# for reproducibility
np.random.seed(seed=42)

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
results_path = Path('results')
if not results_path.exists():
    results_path.mkdir()

# %% [markdown]
# ## Input Data

# %% [markdown]
# ### Generate random data

# %% [markdown]
# The target `y` represents two classes generated by two circular distribution that are not linearly separable because class 0 surrounds class 1.

# %%
# dataset params
N = 50000
factor = 0.1
noise = 0.1

# %%
# generate data
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# ### Visualize Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

# %% [markdown]
# ## Build Keras Model

# %% [markdown]
# Keras supports both a slightly simpler Sequential and more flexible Functional API. We will introduce the former at this point and use the Functional API in more complex examples in the following chapters.
#
# To create a model, we just need to instantiate a Sequential object and provide a list with the sequence of standard layers and their configurations, including the number of units, type of activation function, or name.

# %% [markdown]
# ### Define Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])
# Out:
# 2023-02-17 15:59:29.996235: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-17 15:59:29.998123: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:29.998254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:29.998315: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:31.233606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:31.233775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:31.233785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-02-17 15:59:31.233834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-17 15:59:31.233878: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5947 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# The first hidden layer needs information about the number of features in the matrix it receives from the input layer via the input_shape argument. In our simple case, these are just two. Keras infers the number of rows it needs to process during training, through the batch_size argument that we will pass to the fit method below.
#
# Keras infers the sizes of the inputs received by other layers from the previous layer’s units argument.

# %% [markdown]
# Keras provides numerous standard building blocks, including recurrent and convolutional layers, various options for regularization, a range of loss functions and optimizers, and also preprocessing, visualization and logging (see documentation on GitHub for reference). It is also extensible.
#
# The model’s summary method produces a concise description of the network architecture, including a list of the layer types and shapes, and the number of parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 3)                 9
#
#  logistic (Activation)       (None, 3)                 0
#
#  output (Dense)              (None, 2)                 8
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %% [markdown]
# Next, we compile the Sequential model to configure the learning process. To this end, we define the optimizer, the loss function, and one or several performance metrics to monitor during training:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Tensorboard Callback

# %% [markdown]
# Keras uses callbacks to enable certain functionality during training, such as logging information for interactive display in TensorBoard (see next section):

# %%
tb_callback = TensorBoard(log_dir=results_path / 'tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# ## Train Model

# %% [markdown]
# To train the model, we call its fit method and pass several parameters in addition to the training data:

# %%
training=model.fit(X, 
          Y, 
          epochs=50,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Epoch 1/50
# 2023-02-17 15:59:33.197610: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f70541dfbe0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-17 15:59:33.197666: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 with Max-Q Design, Compute Capability 7.5
# 2023-02-17 15:59:33.224899: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-17 15:59:33.480417: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-02-17 15:59:33.546944: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 [==============================] - 4s 5ms/step - loss: 0.7148 - accuracy: 0.3791 - val_loss: 0.6924 - val_accuracy: 0.4002
# Epoch 2/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6890 - accuracy: 0.6614 - val_loss: 0.6873 - val_accuracy: 0.7286
# Epoch 3/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6828 - accuracy: 0.7549 - val_loss: 0.6794 - val_accuracy: 0.7713
# Epoch 4/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6727 - accuracy: 0.7924 - val_loss: 0.6669 - val_accuracy: 0.8138
# Epoch 5/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6573 - accuracy: 0.8356 - val_loss: 0.6494 - val_accuracy: 0.8310
# Epoch 6/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.6368 - accuracy: 0.8551 - val_loss: 0.6265 - val_accuracy: 0.8580
# Epoch 7/50
# 313/313 [==============================] - 1s 5ms/step - loss: 0.6118 - accuracy: 0.8659 - val_loss: 0.5998 - val_accuracy: 0.8649
# Epoch 8/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5835 - accuracy: 0.8594 - val_loss: 0.5703 - val_accuracy: 0.8619
# Epoch 9/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5533 - accuracy: 0.8623 - val_loss: 0.5402 - val_accuracy: 0.8545
# Epoch 10/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5232 - accuracy: 0.8633 - val_loss: 0.5102 - val_accuracy: 0.8590
# Epoch 11/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4929 - accuracy: 0.8677 - val_loss: 0.4797 - val_accuracy: 0.8655
# Epoch 12/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4623 - accuracy: 0.8716 - val_loss: 0.4492 - val_accuracy: 0.8716
# Epoch 13/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4316 - accuracy: 0.8781 - val_loss: 0.4179 - val_accuracy: 0.8775
# Epoch 14/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3999 - accuracy: 0.8850 - val_loss: 0.3856 - val_accuracy: 0.8868
# Epoch 15/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3678 - accuracy: 0.8945 - val_loss: 0.3531 - val_accuracy: 0.8935
# Epoch 16/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3354 - accuracy: 0.9033 - val_loss: 0.3208 - val_accuracy: 0.9082
# Epoch 17/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3033 - accuracy: 0.9164 - val_loss: 0.2886 - val_accuracy: 0.9226
# Epoch 18/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2717 - accuracy: 0.9344 - val_loss: 0.2578 - val_accuracy: 0.9439
# Epoch 19/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2417 - accuracy: 0.9597 - val_loss: 0.2283 - val_accuracy: 0.9742
# Epoch 20/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2135 - accuracy: 0.9869 - val_loss: 0.2011 - val_accuracy: 0.9937
# Epoch 21/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1873 - accuracy: 0.9961 - val_loss: 0.1761 - val_accuracy: 0.9983
# Epoch 22/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1637 - accuracy: 0.9985 - val_loss: 0.1535 - val_accuracy: 0.9993
# Epoch 23/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1425 - accuracy: 0.9993 - val_loss: 0.1334 - val_accuracy: 0.9995
# Epoch 24/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1236 - accuracy: 0.9995 - val_loss: 0.1155 - val_accuracy: 0.9996
# Epoch 25/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1070 - accuracy: 0.9996 - val_loss: 0.1000 - val_accuracy: 0.9997
# Epoch 26/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0925 - accuracy: 0.9997 - val_loss: 0.0863 - val_accuracy: 0.9998
# Epoch 27/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0800 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 28/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0693 - accuracy: 0.9997 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 29/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0599 - accuracy: 0.9998 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 30/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0519 - accuracy: 0.9998 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 31/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0449 - accuracy: 0.9998 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 32/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0389 - accuracy: 0.9998 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 33/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0338 - accuracy: 0.9998 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 34/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0294 - accuracy: 0.9998 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 35/50
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0256 - accuracy: 0.9998 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 36/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0224 - accuracy: 0.9999 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 37/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0196 - accuracy: 0.9999 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 38/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0172 - accuracy: 0.9998 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 39/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9998 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 40/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9998 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 41/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0119 - accuracy: 0.9998 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 42/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9998 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 43/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9999 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 44/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9999 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 45/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 46/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0069 - accuracy: 0.9999 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 47/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0062 - accuracy: 0.9999 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 48/50
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 49/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 50/50
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0048 - accuracy: 0.9999 - val_loss: 0.0045 - val_accuracy: 1.0000

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
sns.despine()
fig.tight_layout();

# %% [markdown]
# ## Get Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# ## Plot Decision Boundary

# %% [markdown]
# The visualization of the decision boundary resembles the result from the manual network implementation. The training with Keras runs a multiple faster, though.

# %%
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step

# %%
# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
sns.despine()
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir results/tensorboard/
# Out:
# Reusing TensorBoard on port 6006 (pid 9415), started 0:01:37 ago. (Use '!kill 9415' to kill it.)
#       <iframe id="tensorboard-frame-461078cff2bca9fd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-461078cff2bca9fd");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
